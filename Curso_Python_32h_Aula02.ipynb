# %% [markdown]
# <a href="https://colab.research.google.com/github/fernandonakagawa/Curso_Python_32h/blob/main/Curso_Python_32h_Aula02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Curso de Python 32h
# ##Aula 02

# %% [markdown]
# ###Resolução de exercícios do desafio 1

# %%
#tenha como entrada dois números e exiba a sua soma.
n1 = int(input("Digite o primeiro número: "))
n2 = int(input("Digite o segundo número: "))
print("A soma dos números é ", n1+n2, ".")
print("A multiplicação dos números é ", n1+n2, ".")
print("O quadrado do primeiro número é ", n1*n1, ".")
# Out:
# Digite o primeiro número: 3
# Digite o segundo número: 5
# A soma dos números é  8 .
# A multiplicação dos números é  8 .
# O quadrado do primeiro número é  9 .

# %%
"""
Maçãs verdes custam R$ 12,20 por quilo. Cada uma pesa em torno de
130g. Faça um programa que tenha como entrada a quantidade de
maçãs e mostre o valor em reais.
"""
macas = int(input("Digite a quantidade de maçãs: "))
peso_maca = 0.130
preco_kg = 12.20
valor = macas * peso_maca * preco_kg
print("O valor total é de R$", valor)
# Out:
# Digite a quantidade de maçãs: 10
# O valor total é de R$ 15.86

# %%
"""
Ler as notas da 1a. e 2a. avaliações de um aluno. Calcular a
média aritmética simples e escrever a média calculada.
"""
nota1 = float(input("Digite a primeira nota: "))
nota2 = float(input("Digite a segunda nota: "))
media = (nota1 + nota2) / 2
print("A média do aluno é", media)
# Out:
# Digite a primeira nota: 9.5
# Digite a segunda nota: 6.4
# A média do aluno é 7.95

# %%
"""
A jornada de trabalho semanal de um funcionário é de até 40
horas. Escreva um algoritmo que leia o número de horas
trabalhadas em cada semana, o salário por hora e escreva o
salário total do mês do funcionário (considere que o mês possua 4
semanas exatas).
"""
s1 = int(input("Digite o número de horas da primeira semana: "))
s2 = int(input("Digite o número de horas da segunda semana: "))
s3 = int(input("Digite o número de horas da terceira semana: "))
s4 = int(input("Digite o número de horas da quarta semana: "))
salario_hora = float(input("Digite o salário por hora: "))
salario_total = (s1+s2+s3+s4) * salario_hora
print("O salário do mês é de R$", salario_total)
# Out:
# Digite o número de horas da primeira semana: 30
# Digite o número de horas da segunda semana: 36
# Digite o número de horas da terceira semana: 20
# Digite o número de horas da quarta semana: 40
# Digite o salário por hora: 40.75
# O salário do mês é de R$ 5134.5

# %%
"""
A medida de eficiência de um carro é medida em km/l (quantos km o
carro anda com 1 litro de combustível). Faça um algoritmo que
calcule a eficiência de um carro tendo como entrada a distância
percorrida e a quantidade de combustível gasta em litros.
"""
distancia = float(input("Digite a distância percorrida: "))
qtd_combustivel = float(input("Digite a quantidade de combustível: "))
eficiencia = distancia / qtd_combustivel
print("A eficiência é de ", eficiencia,"km/l.")
# Out:
# Digite a distância percorrida: 400
# Digite a quantidade de combustível: 32
# A eficiência é de  12.5 km/l.

# %%
"""
Uma empresa deseja cadastrar em seu banco de dados os nomes de
candidatos à vagas de trabalho. Os nomes são recebidos dos
usuários e é necessário adotar um padrão. Foi decidido que os
nomes estariam todos em letras maiúsculas e sem espaços no início
e no final. Também é desejado que o primeiro nome, nome do meio e
sobrenome seja gravado de forma separada.
"""
#JOSÉ
#ANTUNES DA
#SILVA
nome_completo = "     José Antunes da Silva         "
nome_completo = nome_completo.strip()
nome_completo = nome_completo.upper()
nome_lista = nome_completo.split(" ")
print(nome_lista)
print(type(nome_lista))
primeiro_nome = nome_lista[0]
ultimo_nome = nome_lista[len(nome_lista)-1]
nomes_meio = nome_lista[1:len(nome_lista)-1]
print(primeiro_nome, ultimo_nome)
print(nomes_meio)
# Out:
# ['JOSÉ', 'ANTUNES', 'DA', 'SILVA']
# <class 'list'>
# JOSÉ SILVA
# ['ANTUNES', 'DA']

# %% [markdown]
# ## Aula 02

# %%
a = 10
a += 2
#a = a + 2

if a == 11:
  print(a*2)
elif a == 12:
  print(a*a)
elif a == 13:
  print(a-10)
else:
  print(a/2)
#O código continua a partir daqui
nome = input("Digite um nome: ")
if nome == "Alex":
  print("Sala 01")
elif nome == "João":
  print("Sala 02")
elif nome == "Fernando":
  print("Sala 03")
else:
  print("Erro, nome inválido.")
# Out:
# 144
# Digite um nome: Alex
# Sala 01
# Erro, nome inválido.

# %%
hora = int(input("Digite a hora do dia: "))
if hora < 0:
  print("hora inválida. Deve ser um valor maior ou igual a 0")
elif hora < 6:
  print("Boa madrugada")
elif hora < 12:
  print("Bom dia")
elif hora < 18:
  print("Boa tarde")
elif hora < 24:
  print("Boa noite")
else:
  print("hora inválida, deve ser menor que 24")
# Out:
# Digite a hora do dia: 5
# Bom dia

# %%
a = 10

if a != 0:
  print(a*2)

if a is not 0:
  print(a/2)

if a is 10:
  print(a-2)
# Out:
# 20
# 5.0
# 8

# %%
#a água é molhada - True
#o fogo esfria - False
#o gelo flutua na água - True

#a água é molhada E (and) o gelo flutua na água - True
#a água é molhada OU (or) o fogo esfria - True
#a água é molhada E (and) o fogo esfria - False

a = 10
if a == 10 and a <= 11:
  print(a)
else:
  print(a*10)
# Out:
# 100

# %%
hora = int(input("Digite a hora do dia: "))
if hora >= 0 and hora < 6:
  print("Boa madrugada")
elif hora >= 6 and hora < 12:
  print("Bom dia")
elif hora >= 12 and hora < 18:
  print("Boa tarde")
elif hora >= 18 and hora < 24:
  print("Boa noite")
else:
  print("hora inválida.")
# Out:
# Digite a hora do dia: 24
# hora inválida.

# %%
login = input("Digite o seu login: ")
senha = input("Digite a sua senha: ")
if login == "fernando":
  if senha == "123456":
    print("Seja bem-vindo ao sistema X")
  else:
    print("Senha incorreta.")
else:
  print("Login incorreto.")
# Out:
# Digite o seu login: asd
# Digite a sua senha: 123456
# Login incorreto.

# %%
login = input("Digite o seu login: ")
senha = input("Digite a sua senha: ")
if login == "fernando" and senha == "123456":
  print("Seja bem-vindo.")
else:
  print("Credenciais incorretas.")
# Out:
# Digite o seu login: fernand
# Digite a sua senha: 123456
# Credenciais incorretas.

# %%
from google.colab.patches import cv2_imshow
#import cv2
#img = cv2.imread("/content/drive/MyDrive/SENAI/_2022/Python_32h/aula02/lua.jpg")
#cv2_imshow(img)

hora = int(input("Digite a hora do dia: "))
if hora >= 0 and hora < 6:
  print("Boa madrugada")
  caminho = "/content/drive/MyDrive/SENAI/_2022/Python_32h/aula02/lua.jpg"
elif hora >= 6 and hora < 12:
  print("Bom dia")
  caminho = "/content/drive/MyDrive/SENAI/_2022/Python_32h/aula02/bomdia.png"
elif hora >= 12 and hora < 18:
  print("Boa tarde")
  caminho = "/content/drive/MyDrive/SENAI/_2022/Python_32h/aula02/boatarde.jpg"
elif hora >= 18 and hora < 24:
  print("Boa noite")
  caminho = "/content/drive/MyDrive/SENAI/_2022/Python_32h/aula02/boanoite.png"
else:
  print("hora inválida.")
  #caminho = "/content/drive/MyDrive/SENAI/_2022/Python_32h/aula02/tenor.gif"

img = cv2.imread(caminho)
cv2_imshow(img)
# Out:
# Digite a hora do dia: 22
# Boa noite
# <PIL.Image.Image image mode=RGB size=1280x837 at 0x7F299D369E10>

# %%
#tenha como entrada dois números e exiba a sua divisão. Lembre-se
#que não é possível dividir por 0!

numerador = int(input("Digite o numerador: "))
denominador = int(input("Digite o denominador: "))
if denominador != 0:  
  print(numerador/denominador)
else:
  print("Não é possível dividir por 0!")
# Out:
# Digite o numerador: 6
# Digite o denominador: 4
# 1.5

# %%
if denominador == 0:  
  print("Não é possível dividir por 0!")
else:
  print(numerador/denominador)
# Out:
# 1.5

# %%
"""
As maçãs de um mercado custam R$ 1,30 cada se forem compradas
menos de uma dúzia, e R$ 1,00 se forem compradas pelo menos 12.
Escreva um programa que leia o número de maçãs compradas, calcule
e escreva o custo total da compra.
"""
qtd_macas = int(input("Digite o número de maçãs compradas: "))
if qtd_macas < 12:
  preco = 1.30
else:
  preco = 1.00

print("O valor total é de R$", qtd_macas * preco)
# Out:
# Digite o número de maçãs compradas: -10
# O valor total é de R$ -13.0

# %%
qtd_macas = int(input("Digite o número de maçãs compradas: "))
if qtd_macas > 0:
  if qtd_macas < 12:
    preco = 1.30
  else:
    preco = 1.00
  print("O valor total é de R$", qtd_macas * preco)
else:
  print("Valor \n inválido.")
#o if acaba aqui
print("print")
# Out:
# Digite o número de maçãs compradas: -1
# Valor
#  inválido.
# print

# %% [markdown]
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
# .
# .
# .
# .
# .

# %%
from google.colab.patches import cv2_imshow
img = cv2.imread("/content/lua.jpg")
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=910x683 at 0x7F29A7C273D0>
